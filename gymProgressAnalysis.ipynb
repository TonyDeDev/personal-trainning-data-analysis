# %% [markdown]
# # Gym Progress Analysis Project
#
# This EDA project intend to process and visualize personal workout data exported from two tracking apps. (3 Month later, switched from Strong to Hevy App for workout logging, I just kept the code of cleaning + merging 2 source together)
# It includes data cleaning, standardization, and creation of derived metrics like *work rate*, *frequency*, and *max_1RM*.

# %% [markdown]
# ---
# ## Part 1 - Strong App Data (2022–2024)
# Cleaning and merging two exports from the Strong app into a single structured dataset.

# %%
import pandas as pd

#2 main graphs i want to make: 
#work rate and frequency (muscle group) of over time.
#1 rpm max (specific lift) over time.
df1 = pd.read_csv('data/raw/data_2022-2023.csv')
df2 = pd.read_csv('data/raw/data_2024-2025.csv')
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1586 entries, 0 to 1585
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           1586 non-null   object
#  1   Workout Name   1586 non-null   object
#  2   Duration       1586 non-null   object
#  3   Exercise Name  1586 non-null   object
#  4   Set Order      1586 non-null   object
#  5   Weight         1586 non-null   int64
#  6   Reps           1586 non-null   int64
#  7   Distance       1586 non-null   float64
#  8   Seconds        1586 non-null   int64
#  9   RPE            429 non-null    float64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 124.0+ KB

# %%
#Code for cleaning dataframes
def clean_workout_data(df):
    #Standardize headers
    df.columns = (
        df.columns
        .str.strip()
        .str.lower()
        .str.replace(' ', '_')
    )

    #Drop unnecessary columns safely
    df = df.drop(columns=[
        'workout_name', 'distance', 'seconds', 'rpe', 'notes',
        'kcal', 'name', 'bodyweight', 'set_order', 'category'
    ], errors='ignore')

    #Rename inconsistent columns (if different app formats)
    rename_map = {
        'exercise': 'exercise_name',
    }
    df = df.rename(columns=rename_map)

    #Clean and standardize date
    if 'date' in df.columns:
        df['date'] = pd.to_datetime(df['date'], errors='coerce').dt.date

    #Remove invalid reps (≤ 0 or > 100)
    if 'reps' in df.columns:
        df = df[(df['reps'].fillna(0) > 0) & (df['reps'] <= 40)].reset_index(drop=True)

    #Remove invalid weight (≤ 0)
    if 'weight' in df.columns:
        #Convert to float to avoid dtype assignment warnings
        df['weight'] = pd.to_numeric(df['weight'], errors='coerce').astype(float)
        
        #Fix very large weights (accidental extra zero)
        df.loc[df['weight'] > 1000, 'weight'] = df['weight'] / 10
        
        #Remove zero or negative weights
        df = df[df['weight'].fillna(0) > 0].reset_index(drop=True)

    #Drop rows with critical missing data
    critical_cols = [col for col in ['date', 'exercise_name', 'workout_end'] if col in df.columns]
    df = df.dropna(subset=critical_cols).reset_index(drop=True)

    #Add week and year columns if date is valid
    if 'date' in df.columns:
        df['week'] = df['date'].apply(lambda x: x.isocalendar().week if pd.notnull(x) else None)
        df['year'] = df['date'].apply(lambda x: x.isocalendar().year if pd.notnull(x) else None)

    return df


#Clean both app dataframes
df1 = clean_workout_data(df1)
df2 = clean_workout_data(df2)

# %%
#I noticed that df1 has the date split into start and end. 
#for simplicity, I will just use the same format with df2 and have a single date column.
#I will first find the duration of work out by subtracting start from end, then convert to minutes.
df1['workout_start'] = pd.to_datetime(df1['workout_start'])
df1['workout_end'] = pd.to_datetime(df1['workout_end'])

#Calculate duration in minutes
df1['duration_min'] = (df1['workout_end'] - df1['workout_start']).dt.total_seconds() / 60

#One problem with this dataset is that i often input the end date to be 1 day before the start date by mistake.
#To fix this, I will add the day difference if the duration is negative.
df1['duration_min'] = df1['duration_min'].apply(lambda x: x + 24*60 if x < 0 else x)

#Keep just the date for mergin purposes later
df1['date'] = df1['workout_start'].dt.date

#Before cleaning df1, date was not in cols so week and year cols were not created.
#Now, I will create them here.
df1['year'] = pd.to_datetime(df1['date']).dt.isocalendar().year
df1['week'] = pd.to_datetime(df1['date']).dt.isocalendar().week

#Drop the start and end columns if no longer needed
df1 = df1.drop(columns=['workout_start', 'workout_end'])

# %%
#Convert duration like "1h 30min" or "45min" into total minutes
df2['duration_min'] = (
    df2['duration']
    .str.replace(" ", "") 
    .apply(lambda x: pd.to_timedelta(x).total_seconds() / 60 if pd.notna(x) else None)
    .astype('float')
)

#Drop original duration columns safely
df1 = df1.drop(columns=['duration'], errors='ignore')
df2 = df2.drop(columns=['duration'], errors='ignore')

# %%
#For some of the data, i often forgot to stop the workout, causing inflated values for duration.
#To fix this, I replace any duration values over 180 minutes with the means of other durations that are less than 180 minutes.
def fix_inflated_durations(df, col='duration_min', max_valid=180):
    #Ensure column is float type to avoid dtype assignment warnings
    df[col] = df[col].astype(float)

    #Compute mean of valid durations
    valid_mean = df.loc[df[col] <= max_valid, col].mean()

    #Replace inflated values
    df.loc[df[col] > max_valid, col] = valid_mean

    #Round to whole minutes
    df[col] = df[col].round(0).astype(int)

    return df


# Apply to both dataframes
df1 = fix_inflated_durations(df1)
df2 = fix_inflated_durations(df2)

# %%
#Check the name variations in both datasets and see how to map them
print(df1['exercise_name'].dropna().unique())
print(df2['exercise_name'].dropna().unique())
# Out:
# ['Pull Up' 'T-Bar row' 'Bird dog row' 'Dumbbell delt '
#  'Dumbbell Bicep Curl' 'Hammer Curl' 'Bench Press' 'Dips'
#  'Single Leg KB Overhead Press' 'Dumbbell Lateral Raises' 'Squat'
#  'Incline Dumbbell Press' 'Banded pull apart' 'Medicine ball slam'
#  'Crunches' 'Hammer strenght high row' 'Lat pushdown' 'Cable Row'
#  'Shoulder Dumbbell Press' 'Cable delt ' 'Heavy lateral raise + 10 shrug'
#  'Lat pulldown' 'Hammer strenght medium row' 'Pushdowns' 'Leg Extensions'
#  'Calf Raises' 'Preacher curl' 'High to low cable chest fly'
#  'Low to high cable chest fly' 'Leg Curls' 'Dumbbell RDL'
#  'Over-head tricep cable' 'Grip strenghten exercise' 'Single arm pushdown'
#  'Incline dumbbell curl' 'Lateral cable raise' 'Abs roller']
# ['Incline Bench Press (Smith Machine)' 'Lat Pulldown (Cable)'
#  'Bench Press (Smith Machine)' 'Preacher Curl (Machine)'
#  'Triceps Extension' 'Hack Squat' 'Lying Leg Curl (Machine)'
#  'Leg Extension (Machine)' 'Lateral Raise (Cable)' 'Reverse Fly (Cable)'
# ...

# %%
#Normalize exercise names to lowercase and normalize machine type
def normalize_exercise_names(df):
    df['exercise_name'] = (
        df['exercise_name']
        .str.lower()
        .str.strip()
        .str.replace(r'\s+', ' ', regex=True)
        .str.strip()
    )
    return df


df1 = normalize_exercise_names(df1)
df2 = normalize_exercise_names(df2)


#remove exercises that do not target specific muscle groups (like warmup exercises and cardio)
#For the first dataset, it was early in my trainning journey so i did more questionable exercises.
#I will remove any it as it does not contributed to my current goals.
unwanted_exercises = ['stretching', 'running (treadmill)', 'banded pull apart',
                      'bird dog row', 'single leg kb overhead press',
                      'medicine ball slam', 'grip strenghten exercise',
                      "lower back hyper extend", 'box single leg jumb',
                      'static squad jumb', "piston squad", "jm press", 
                      'decline bench press (barbell)']
df1 = df1[~df1['exercise_name'].isin(unwanted_exercises)]
df2 = df2[~df2['exercise_name'].isin(unwanted_exercises)]

#Now I translate both datasets to have consistent exercise names
#Also group up similar exercises into one standard name
name_map = {
    #chest
    'bench press': 'bench press (barbell)',
    'incline dumbbell press': 'incline bench press (dumbbell)',
    'push up plyo explosive': 'push up',
    'high to low cable chest fly': 'cable crossover',
    'low to high cable chest fly': 'cable crossover',

    #triceps
    'dips': 'triceps dip',
    'over-head tricep cable': 'triceps extension',
    'single arm pushdown': 'triceps extension',
    'pushdowns': 'triceps extension',

    #biceps
    'dumbbell bicep curl': 'bicep curl (cable)',
    'hammer curl': 'bicep curl (cable)',
    'incline dumbbell curl': 'bicep curl (cable)',
    'preacher curl': 'preacher curl (machine)',

    #shoulders
    'shoulder dumbbell press': 'overhead press (smith machine)',
    'lateral cable raise': 'lateral raise (cable)',
    'dumbbell lateral raises': 'lateral raise (dumbbell)',
    'heavy lateral raise + 10 shrug': 'lateral raise (dumbbell)',
    'cable delt': 'reverse fly (cable)',
    'dumbbell delt': 'reverse fly (cable)',

    #back
    'scalp pull up': 'pull up',
    'lat pulldown': 'lat pulldown (cable)',
    'lat pulldown - wide grip (cable)': 'lat pulldown (cable)',
    'lat pushdown': 'lat pulldown (cable)',
    'hammer strenght high row': 'seated wide-grip row (cable)',
    't-bar row': 'seated wide-grip row (cable)',
    't bar row': 'seated wide-grip row (cable)',
    'hammer strenght medium row': 'seated row (machine)',
    'cable row': 'seated row (cable)',

    #legs
    'leg press': 'squat (barbell)',
    'squat': 'squat (barbell)',
    'hack squat': 'hack squat (machine)',
    'pendulum squat': 'pendulum squat (machine)',
    'leg extensions': 'leg extension (machine)',
    'leg curls': 'lying leg curl (machine)',
    'dumbbell rdl': 'seated leg curl (machine)',
    'romanian deadlift': 'seated leg curl (machine)',
    'rdl': 'seated leg curl (machine)',
    'seated leg curl': 'seated leg curl (machine)',
    'romanian deadlift (barbell)': 'seated leg curl (machine)',

    #calves
    'calf raises': 'seated calf raise (machine)',
    'calf press on leg press': 'calf press (machine)',
    'calf press on seated leg press': 'calf press (machine)',

    #core
    'crunches': 'crunch (machine)',
    'abs roller': 'crunch (machine)',
    'leg raises': 'leg raises'
}


#Apply mappings to both dataframes
df1['exercise_name'] = df1['exercise_name'].replace(name_map)
df2['exercise_name'] = df2['exercise_name'].replace(name_map)


print(df1['exercise_name'].dropna().unique())
print(df2['exercise_name'].dropna().unique())
# Out:
# ['pull up' 'seated wide-grip row (cable)' 'reverse fly (cable)'
#  'bicep curl (cable)' 'bench press (barbell)' 'triceps dip'
#  'lateral raise (dumbbell)' 'squat (barbell)'
#  'incline bench press (dumbbell)' 'crunch (machine)'
#  'lat pulldown (cable)' 'seated row (cable)'
#  'overhead press (smith machine)' 'seated row (machine)'
#  'triceps extension' 'leg extension (machine)'
#  'seated calf raise (machine)' 'preacher curl (machine)' 'cable crossover'
#  'lying leg curl (machine)' 'seated leg curl (machine)'
#  'lateral raise (cable)']
# ['incline bench press (smith machine)' 'lat pulldown (cable)'
#  'bench press (smith machine)' 'preacher curl (machine)'
#  'triceps extension' 'hack squat (machine)' 'lying leg curl (machine)'
#  'leg extension (machine)' 'lateral raise (cable)' 'reverse fly (cable)'
#  'calf press (machine)' 'seated row (cable)' 'bicep curl (cable)'
#  'seated wide-grip row (cable)' 'reverse fly (machine)' 'chest fly'
# ...

# %%
#After making the columns consistent between both datasets, I can now combine them for easier analysis later
df_combined = pd.concat([df1, df2], ignore_index=True)


#The next part is from a new app/source  as i switch on to using Hevy app to track my workouts. 
#However the code a bove help clean my data to import the data set into hevy

# %% [markdown]
# ---
# ## Part 2 - Hevy App Data: Cleaning & Feature Engineering
#
# The Hevy export has a different schema to the Strong app:
# - No `date` column - duration must be derived from `start_time` and `end_time`
# - Exercise column is named `exercise_title` (not `exercise_name`)
# - Several columns are entirely empty and can be dropped (`description`, `superset_id`, `exercise_notes`)

# %%
df3 = pd.read_csv('data/raw/workout_data.csv')
print(df3.shape)
df3.head(3)
# Out:
# (3161, 14)
#         title          start_time            end_time  description  \
# 0  Lower body  27 Mar 2026, 17:35  27 Mar 2026, 18:10          NaN
# 1  Lower body  27 Mar 2026, 17:35  27 Mar 2026, 18:10          NaN
# 2  Lower body  27 Mar 2026, 17:35  27 Mar 2026, 18:10          NaN
#
#     exercise_title  superset_id  exercise_notes  set_index set_type  \
# 0  Squat (Barbell)          NaN             NaN          0   warmup
# 1  Squat (Barbell)          NaN             NaN          1   normal
# 2  Squat (Barbell)          NaN             NaN          2   normal
#
#    weight_lbs  reps  distance_km  duration_seconds  rpe
# 0       225.0   5.0          NaN               NaN  NaN
# 1       280.0   5.0          NaN               NaN  NaN
# 2       280.0   5.0          NaN               NaN  NaN

# %% [markdown]
# ### 2.1 Cleaning Plan
#
# Before writing any code, here is what needs to happen to make df3 usable:
#
# 1. **Drop always-empty columns** - `description`, `superset_id`, `exercise_notes` are 0 non-null. No information, no reason to keep them.
# 2. **Parse timestamps and compute duration** - `start_time` and `end_time` are stored as strings. Subtracting them gives session duration in minutes. Same approach as df1, but the column names are different.
# 3. **Extract date** - pull just the date from `start_time` for grouping.
# 4. **Normalize Weight** - Change lbs/kg to just weight
# 5. **Filter invalid reps and weight** - same rules as before: reps must be 1–40, weight must be > 0.
# 6. **Rename `exercise_title` → `exercise_name`** - consistent naming across all datasets.
# 7. **Add `week` and `year` columns** - needed for frequency calculation later.

# %%
#1. Drop always-empty columns
df3 = df3.drop(columns=['description', 'superset_id', 'exercise_notes'], errors='ignore')

#2. Parse timestamps
df3['start_time'] = pd.to_datetime(df3['start_time'])
df3['end_time']   = pd.to_datetime(df3['end_time'])

#3. Compute duration in minutes (end - start)
df3['duration_min'] = (df3['end_time'] - df3['start_time']).dt.total_seconds() / 60

#4. Extract date from start_time
df3['date'] = df3['start_time'].dt.date

#5. Drop timestamp columns - no longer needed
df3 = df3.drop(columns=['start_time', 'end_time'])

#6. Convert weight from lbs to kg
df3 = df3.rename(columns={
    'weight_lbs': 'weight',
    'weight_kgs': 'weight'
})

#7. Filter invalid reps
df3['reps'] = pd.to_numeric(df3['reps'], errors='coerce')
df3 = df3[(df3['reps'].fillna(0) > 0) & (df3['reps'] <= 40)].reset_index(drop=True)

#8. Filter invalid weight
df3['weight'] = pd.to_numeric(df3['weight'], errors='coerce')
df3 = df3[df3['weight'].fillna(0) >= 0].reset_index(drop=True)

#9. Rename exercise column for consistency
df3 = df3.rename(columns={'exercise_title': 'exercise_name'})

#10. Add week and year
df3['year'] = pd.to_datetime(df3['date']).dt.isocalendar().year.astype(int)
df3['week'] = pd.to_datetime(df3['date']).dt.isocalendar().week.astype(int)

print(f'df3 after cleaning: {df3.shape[0]:,} rows x {df3.shape[1]} cols')
df3.head(3)
# Out:
# df3 after cleaning: 3,083 rows x 13 cols
#         title    exercise_name  set_index set_type  weight  reps  distance_km  \
# 0  Lower body  Squat (Barbell)          0   warmup   225.0   5.0          NaN
# 1  Lower body  Squat (Barbell)          1   normal   280.0   5.0          NaN
# 2  Lower body  Squat (Barbell)          2   normal   280.0   5.0          NaN
#
#    duration_seconds  rpe  duration_min        date  year  week
# 0               NaN  NaN          35.0  2026-03-27  2026    13
# 1               NaN  NaN          35.0  2026-03-27  2026    13
# 2               NaN  NaN          35.0  2026-03-27  2026    13

# %% [markdown]
# ### 2.2 Muscle Group Mapping
#
# Hevy exports exercise names in title case with parentheses (e.g. `'Bench Press (Barbell)'`) - different from the lowercase Strong format in df1/df2, so no renaming is needed here. The `MUSCLE_MAP` covers every exercise in the Hevy library with up to three muscle groups per entry `(Primary, Secondary, Tertiary)`. We only extract index `[0]` - the primary muscle group - to keep grouping simple and consistent with the rest of the analysis.

# %%
#See what exercises are in df3 before mapping
print(f'Unique exercises in df3: {df3["exercise_name"].nunique()}')
print(sorted(df3['exercise_name'].dropna().unique()))
# Out:
# Unique exercises in df3: 60
# ...

# %%
#Hevy exercise library - primary muscle group only
MUSCLE_MAP = {
    # Chest
    'Bench Press (Barbell)':                   'Chest',
    'Bench Press (Dumbbell)':                  'Chest',
    'Bench Press (Smith Machine)':             'Chest',
    'Bench Press (Cable)':                     'Chest',
    'Bench Press - Close Grip (Barbell)':      'Triceps',
    'Bench Press - Wide Grip (Barbell)':       'Chest',
    'Incline Bench Press (Barbell)':           'Chest',
    'Incline Bench Press (Dumbbell)':          'Chest',
    'Incline Bench Press (Smith Machine)':     'Chest',
    'Incline Chest Fly (Dumbbell)':            'Chest',
    'Incline Chest Press (Machine)':           'Chest',
    'Decline Bench Press (Barbell)':           'Chest',
    'Decline Bench Press (Dumbbell)':          'Chest',
    'Decline Bench Press (Machine)':           'Chest',
    'Decline Bench Press (Smith Machine)':     'Chest',
    'Decline Chest Fly (Dumbbell)':            'Chest',
    'Chest Fly (Dumbbell)':                    'Chest',
    'Chest Fly (Machine)':                     'Chest',
    'Chest Fly (Band)':                        'Chest',
    'Chest Fly (Suspension)':                  'Chest',
    'Chest Press (Machine)':                   'Chest',
    'Chest Press (Band)':                      'Chest',
    'Cable Fly Crossovers':                    'Chest',
    'Low Cable Fly Crossovers':                'Chest',
    'Seated Chest Flys (Cable)':               'Chest',
    'Single Arm Cable Crossover':              'Chest',
    'Iso-Lateral Chest Press (Machine)':       'Chest',
    'Push Up':                                 'Chest',
    'Push Up (Weighted)':                      'Chest',
    'Push Up - Close Grip':                    'Triceps',
    'Decline Push Up':                         'Chest',
    'Incline Push Ups':                        'Chest',
    'Clap Push Ups':                           'Chest',
    'Kneeling Push Up':                        'Chest',
    'Plank Pushup':                            'Chest',
    'Ring Push Up':                            'Chest',
    'One Arm Push Up':                         'Chest',
    'Chest Dip':                               'Chest',
    'Chest Dip (Assisted)':                    'Chest',
    'Chest Dip (Weighted)':                    'Chest',
    'Dumbbell Squeeze Press':                  'Chest',
    'Hex Press (Dumbbell)':                    'Chest',
    'Floor Press (Barbell)':                   'Chest',
    'Floor Press (Dumbbell)':                  'Chest',
    'Feet Up Bench Press (Barbell)':           'Chest',
    'Around The World':                        'Chest',
    'Plate Press':                             'Chest',
    'Plate Squeeze (Svend Press)':             'Chest',
    # Shoulders
    'Overhead Press (Barbell)':                'Shoulders',
    'Overhead Press (Dumbbell)':               'Shoulders',
    'Overhead Press (Smith Machine)':          'Shoulders',
    'Shoulder Press (Dumbbell)':               'Shoulders',
    'Shoulder Press (Machine Plates)':         'Shoulders',
    'Seated Overhead Press (Barbell)':         'Shoulders',
    'Seated Overhead Press (Dumbbell)':        'Shoulders',
    'Seated Shoulder Press (Machine)':         'Shoulders',
    'Standing Military Press (Barbell)':       'Shoulders',
    'Arnold Press (Dumbbell)':                 'Shoulders',
    'Push Press':                              'Shoulders',
    'Single Arm Landmine Press (Barbell)':     'Shoulders',
    'Handstand Push Up':                       'Shoulders',
    'Pike Pushup':                             'Shoulders',
    'Lateral Raise (Dumbbell)':                'Shoulders',
    'Lateral Raise (Cable)':                   'Shoulders',
    'Lateral Raise (Machine)':                 'Shoulders',
    'Lateral Raise (Band)':                    'Shoulders',
    'Seated Lateral Raise (Dumbbell)':         'Shoulders',
    'Single Arm Lateral Raise (Cable)':        'Shoulders',
    'Front Raise (Dumbbell)':                  'Shoulders',
    'Front Raise (Barbell)':                   'Shoulders',
    'Front Raise (Cable)':                     'Shoulders',
    'Front Raise (Band)':                      'Shoulders',
    'Front Raise (Suspension)':                'Shoulders',
    'Plate Front Raise':                       'Shoulders',
    'Overhead Plate Raise':                    'Shoulders',
    'Upright Row (Barbell)':                   'Shoulders',
    'Upright Row (Cable)':                     'Shoulders',
    'Upright Row (Dumbbell)':                  'Shoulders',
    'Shoulder Taps':                           'Shoulders',
    'Kettlebell Halo':                         'Shoulders',
    'Kettlebell Shoulder Press':               'Shoulders',
    # Rear Delts
    'Face Pull':                               'Rear Delts',
    'Rear Delt Reverse Fly (Cable)':           'Rear Delts',
    'Rear Delt Reverse Fly (Dumbbell)':        'Rear Delts',
    'Rear Delt Reverse Fly (Machine)':         'Rear Delts',
    'Chest Supported Reverse Fly (Dumbbell)':  'Rear Delts',
    'Reverse Fly Single Arm (Cable)':          'Rear Delts',
    'Chest Supported Y Raise (Dumbbell)':      'Rear Delts',
    'Band Pullaparts':                         'Rear Delts',
    # Biceps
    'Bicep Curl (Barbell)':                    'Biceps',
    'Bicep Curl (Cable)':                      'Biceps',
    'Bicep Curl (Dumbbell)':                   'Biceps',
    'Bicep Curl (Machine)':                    'Biceps',
    'Bicep Curl (Suspension)':                 'Biceps',
    'EZ Bar Biceps Curl':                      'Biceps',
    'Preacher Curl (Barbell)':                 'Biceps',
    'Preacher Curl (Dumbbell)':                'Biceps',
    'Preacher Curl (Machine)':                 'Biceps',
    'Concentration Curl':                      'Biceps',
    'Hammer Curl (Dumbbell)':                  'Biceps',
    'Hammer Curl (Cable)':                     'Biceps',
    'Hammer Curl (Band)':                      'Biceps',
    'Cross Body Hammer Curl':                  'Biceps',
    'Seated Incline Curl (Dumbbell)':          'Biceps',
    'Spider Curl (Barbell)':                   'Biceps',
    'Spider Curl (Dumbbell)':                  'Biceps',
    'Drag Curl':                               'Biceps',
    'Overhead Curl (Cable)':                   'Biceps',
    'Behind the Back Curl (Cable)':            'Biceps',
    'Rope Cable Curl':                         'Biceps',
    'Reverse Curl (Barbell)':                  'Biceps',
    'Reverse Curl (Cable)':                    'Biceps',
    'Reverse Curl (Dumbbell)':                 'Biceps',
    'Reverse Grip Concentration Curl':         'Biceps',
    'Pinwheel Curl (Dumbbell)':                'Biceps',
    'Waiter Curl (Dumbbell)':                  'Biceps',
    'Plate Curl':                              'Biceps',
    'Zottman Curl (Dumbbell)':                 'Biceps',
    'Kettlebell Curl':                         'Biceps',
    '21s Bicep Curl':                          'Biceps',
    'Single Arm Curl (Cable)':                 'Biceps',
    # Triceps
    'Triceps Dip':                             'Triceps',
    'Triceps Dip (Assisted)':                  'Triceps',
    'Triceps Dip (Weighted)':                  'Triceps',
    'Triceps Extension (Barbell)':             'Triceps',
    'Triceps Extension (Cable)':               'Triceps',
    'Triceps Extension (Dumbbell)':            'Triceps',
    'Triceps Extension (Machine)':             'Triceps',
    'Triceps Extension (Suspension)':          'Triceps',
    'Overhead Triceps Extension (Cable)':      'Triceps',
    'Triceps Pushdown':                        'Triceps',
    'Triceps Rope Pushdown':                   'Triceps',
    'Triceps Pressdown':                       'Triceps',
    'Triceps Kickback (Cable)':                'Triceps',
    'Triceps Kickback (Dumbbell)':             'Triceps',
    'Single Arm Tricep Extension (Dumbbell)':  'Triceps',
    'Single Arm Triceps Pushdown (Cable)':     'Triceps',
    'Skullcrusher (Barbell)':                  'Triceps',
    'Skullcrusher (Dumbbell)':                 'Triceps',
    'JM Press (Barbell)':                      'Triceps',
    'Seated Triceps Press':                    'Triceps',
    'Seated Dip Machine':                      'Triceps',
    'Floor Triceps Dip':                       'Triceps',
    'Bench Dip':                               'Triceps',
    'Diamond Push Up':                         'Triceps',
    'Wide-Elbow Triceps Press (Dumbbell)':     'Triceps',
    # Upper Back
    'Bent Over Row (Barbell)':                 'Upper Back',
    'Bent Over Row (Dumbbell)':                'Upper Back',
    'Bent Over Row (Band)':                    'Upper Back',
    'T Bar Row':                               'Upper Back',
    'Seated Cable Row - V Grip (Cable)':       'Upper Back',
    'Seated Cable Row - Bar Grip':             'Upper Back',
    'Seated Cable Row - Bar Wide Grip':        'Upper Back',
    'Seated Row (Machine)':                    'Upper Back',
    'Iso-Lateral Row (Machine)':               'Upper Back',
    'Iso-Lateral High Row (Machine)':          'Lats',
    'Chest Supported Incline Row (Dumbbell)':  'Upper Back',
    'Inverted Row':                            'Upper Back',
    'Pendlay Row (Barbell)':                   'Upper Back',
    'Meadows Rows (Barbell)':                  'Upper Back',
    'Landmine Row':                            'Upper Back',
    'Single Arm Cable Row':                    'Upper Back',
    'Dumbbell Row':                            'Upper Back',
    'Renegade Row (Dumbbell)':                 'Upper Back',
    'Gorilla Row (Kettlebell)':                'Upper Back',
    'Rack Pull':                               'Upper Back',
    'Low Row (Suspension)':                    'Upper Back',
    'Scapular Pull Ups':                       'Upper Back',
    'Dead Hang':                               'Upper Back',
    'Kelso shrug machine row':                 'Upper Back',
    # Lats
    'Lat Pulldown (Cable)':                    'Lats',
    'Lat Pulldown (Band)':                     'Lats',
    'Lat Pulldown (Machine)':                  'Lats',
    'Lat Pulldown - Close Grip (Cable)':       'Lats',
    'Reverse Grip Lat Pulldown (Cable)':       'Lats',
    'Single Arm Lat Pulldown':                 'Lats',
    'Kneeling Pulldown (band)':                'Lats',
    'Straight Arm Lat Pulldown (Cable)':       'Lats',
    'Rope Straight Arm Pulldown':              'Lats',
    'Pull Up':                                 'Lats',
    'Pull Up (Assisted)':                      'Lats',
    'Pull Up (Band)':                          'Lats',
    'Pull Up (Weighted)':                      'Lats',
    'Wide Pull Up':                            'Lats',
    'Chin Up':                                 'Lats',
    'Chin Up (Assisted)':                      'Lats',
    'Chin Up (Weighted)':                      'Lats',
    'Negative Pull Up':                        'Lats',
    'Kipping Pull Up':                         'Lats',
    'Ring Pull Up':                            'Lats',
    'Sternum Pull up (Gironda)':               'Lats',
    'Pullover (Dumbbell)':                     'Lats',
    'Pullover (Machine)':                      'Lats',
    'Vertical Traction (Machine)':             'Lats',
    # Lower Back
    'Back Extension (Hyperextension)':         'Lower Back',
    'Back Extension (Machine)':                'Lower Back',
    'Back Extension (Weighted Hyperextension)':'Lower Back',
    'Good Morning (Barbell)':                  'Lower Back',
    'Superman':                                'Lower Back',
    'Reverse Hyperextension':                  'Lower Back',
    # Traps
    'Shrug (Barbell)':                         'Traps',
    'Shrug (Cable)':                           'Traps',
    'Shrug (Dumbbell)':                        'Traps',
    'Shrug (Machine)':                         'Traps',
    'Shrug (Smith Machine)':                   'Traps',
    # Forearms
    'Behind the Back Bicep Wrist Curl (Barbell)': 'Forearms',
    'Seated Palms Up Wrist Curl':              'Forearms',
    'Seated Wrist Extension (Barbell)':        'Forearms',
    'Wrist Roller':                            'Forearms',
    # Abdominals
    'Crunch': 'Abdominals', 'Crunch (Machine)': 'Abdominals',
    'Crunch (Weighted)': 'Abdominals', 'Decline Crunch': 'Abdominals',
    'Decline Crunch (Weighted)': 'Abdominals', 'Sit Up': 'Abdominals',
    'Sit Up (Weighted)': 'Abdominals', 'Jackknife Sit Up': 'Abdominals',
    'Hanging Knee Raise': 'Abdominals', 'Hanging Leg Raise': 'Abdominals',
    'Lying Knee Raise': 'Abdominals', 'Lying Leg Raise': 'Abdominals',
    'Leg Raise Parallel Bars': 'Abdominals', 'Knee Raise Parallel Bars': 'Abdominals',
    'Toes to Bar': 'Abdominals', 'Cable Crunch': 'Abdominals',
    'Cable Core Palloff Press': 'Abdominals', 'Cable Twist (Down to up)': 'Abdominals',
    'Cable Twist (Up to down)': 'Abdominals', 'Plank': 'Abdominals',
    'Side Plank': 'Abdominals', 'Reverse Plank': 'Abdominals',
    'Ab Wheel': 'Abdominals', 'Ab Scissors': 'Abdominals',
    'Hollow Rock': 'Abdominals', 'Dead Bug': 'Abdominals',
    'Dragon Flag': 'Abdominals', 'Dragonfly': 'Abdominals',
    'Flutter Kicks': 'Abdominals', 'Heel Taps': 'Abdominals',
    'V Up': 'Abdominals', 'Bicycle Crunch': 'Abdominals',
    'Bicycle Crunch Raised Legs': 'Abdominals', 'Oblique Crunch': 'Abdominals',
    'Russian Twist (Bodyweight)': 'Abdominals', 'Russian Twist (Weighted)': 'Abdominals',
    'Side Bend': 'Abdominals', 'Side Bend (Dumbbell)': 'Abdominals',
    'Landmine 180': 'Abdominals', 'Torso Rotation': 'Abdominals',
    'Toe Touch': 'Abdominals', 'Jack Knife (Suspension)': 'Abdominals',
    'Spiderman': 'Abdominals', 'Elbow to Knee': 'Abdominals',
    'L-Sit Hold': ' ',
    # Neck
    'Lying Neck Curls': 'Neck', 'Lying Neck Curls (Weighted)': 'Neck',
    'Lying Neck Extension': 'Neck', 'Lying Neck Extension (Weighted)': 'Neck',
    # Quadriceps
    'Squat (Barbell)':                         'Quadriceps',
    'Squat (Bodyweight)':                      'Quadriceps',
    'Squat (Dumbbell)':                        'Quadriceps',
    'Squat (Machine)':                         'Quadriceps',
    'Squat (Smith Machine)':                   'Quadriceps',
    'Squat (Band)':                            'Quadriceps',
    'Front Squat':                             'Quadriceps',
    'Full Squat':                              'Quadriceps',
    'Box Squat (Barbell)':                     'Quadriceps',
    'Pause Squat (Barbell)':                   'Quadriceps',
    'Overhead Squat':                          'Quadriceps',
    'Hack Squat':                              'Quadriceps',
    'Hack Squat (Machine)':                    'Quadriceps',
    'Pendulum Squat (Machine)':                'Quadriceps',
    'Goblet Squat':                            'Quadriceps',
    'Kettlebell Goblet Squat':                 'Quadriceps',
    'Sumo Squat':                              'Quadriceps',
    'Sumo Squat (Barbell)':                    'Quadriceps',
    'Sumo Squat (Dumbbell)':                   'Quadriceps',
    'Sumo Squat (Kettlebell)':                 'Quadriceps',
    'Leg Press (Machine)':                     'Quadriceps',
    'Leg Press Horizontal (Machine)':          'Quadriceps',
    'Single Leg Press (Machine)':              'Quadriceps',
    'Leg Extension (Machine)':                 'Quadriceps',
    'Leg Extensions (Machine)':                'Quadriceps',
    'Single Leg Extensions':                   'Quadriceps',
    'Lunge':                                   'Quadriceps',
    'Lunge (Barbell)':                         'Quadriceps',
    'Lunge (Dumbbell)':                        'Quadriceps',
    'Reverse Lunge':                           'Quadriceps',
    'Reverse Lunge (Barbell)':                 'Quadriceps',
    'Reverse Lunge (Dumbbell)':                'Quadriceps',
    'Walking Lunge':                           'Quadriceps',
    'Walking Lunge (Dumbbell)':                'Quadriceps',
    'Bulgarian Split Squat':                   'Quadriceps',
    'Split Squat (Dumbbell)':                  'Quadriceps',
    'Lateral Lunge':                           'Quadriceps',
    'Lateral Squat':                           'Quadriceps',
    'Curtsy Lunge (Dumbbell)':                 'Quadriceps',
    'Overhead Dumbbell Lunge':                 'Quadriceps',
    'Pistol Squat':                            'Quadriceps',
    'Assisted Pistol Squats':                  'Quadriceps',
    'Piston Squat':                            'Quadriceps',
    'Step Up':                                 'Quadriceps',
    'Dumbbell Step Up':                        'Quadriceps',
    'Box Jump':                                'Quadriceps',
    'Lateral Box Jump':                        'Quadriceps',
    'Jump Squat':                              'Quadriceps',
    'Jumping Lunge':                           'Quadriceps',
    'Frog Jumps':                              'Quadriceps',
    'Sissy Squat (Weighted)':                  'Quadriceps',
    'Wall Sit':                                'Quadriceps',
    'Belt Squat (Machine)':                    'Quadriceps',
    # Abductors / Adductors
    'Hip Abduction (Machine)':                 'Hamstrings',
    'Hip Adduction (Machine)':                 'Quadriceps',
    # Hamstrings
    'Romanian Deadlift (Barbell)':             'Hamstrings',
    'Romanian Deadlift (Dumbbell)':            'Hamstrings',
    'Single Leg Romanian Deadlift (Barbell)':  'Hamstrings',
    'Single Leg Romanian Deadlift (Dumbbell)': 'Hamstrings',
    'Straight Leg Deadlift':                   'Hamstrings',
    'Seated Leg Curl (Machine)':               'Hamstrings',
    'Lying Leg Curl (Machine)':                'Hamstrings',
    'Standing Leg Curls':                      'Hamstrings',
    'Nordic Hamstrings Curls':                 'Hamstrings',
    'Glute Ham Raise':                         'Hamstrings',
    # Glutes
    'Deadlift (Barbell)':                      'Glutes',
    'Deadlift (Dumbbell)':                     'Glutes',
    'Deadlift (Smith Machine)':                'Glutes',
    'Deadlift (Trap bar)':                     'Glutes',
    'Deadlift (Band)':                         'Glutes',
    'Sumo Deadlift':                           'Glutes',
    'Hip Thrust (Barbell)':                    'Glutes',
    'Hip Thrust (Machine)':                    'Glutes',
    'Hip Thrust (Smith Machine)':              'Glutes',
    'Hip Thrust':                              'Glutes',
    'Glute Bridge':                            'Glutes',
    'Single Leg Glute Bridge':                 'Glutes',
    'Single Leg Hip Thrust':                   'Glutes',
    'Single Leg Hip Thrust (Dumbbell)':        'Glutes',
    'Partial Glute Bridge (Barbell)':          'Glutes',
    'Frog Pumps (Dumbbell)':                   'Glutes',
    'Glute Kickback (Machine)':                'Glutes',
    'Glute Kickback on Floor':                 'Glutes',
    'Standing Cable Glute Kickbacks':          'Glutes',
    'Rear Kick (Machine)':                     'Glutes',
    'Clamshell':                               'Glutes',
    'Lateral Band Walks':                      'Glutes',
    'Lateral Leg Raises':                      'Glutes',
    'Fire Hydrants':                           'Glutes',
    'Bird Dog':                                'Glutes',
    'Cable Pull Through':                      'Glutes',
    # Calves
    'Standing Calf Raise (Machine)': 'Calves', 'Standing Calf Raise': 'Calves',
    'Standing Calf Raise (Barbell)': 'Calves', 'Standing Calf Raise (Dumbbell)': 'Calves',
    'Standing Calf Raise (Smith)': 'Calves', 'Seated Calf Raise': 'Calves',
    'Calf Extension (Machine)': 'Calves', 'Calf Press (Machine)': 'Calves',
    'Single Leg Standing Calf Raise': 'Calves',
    'Single Leg Standing Calf Raise (Barbell)': 'Calves',
    'Single Leg Standing Calf Raise (Dumbbell)': 'Calves',
    'Single Leg Standing Calf Raise (Machine)': 'Calves',
    # Cardio
    'Treadmill': 'Cardio', 'Running': 'Cardio', 'Cycling': 'Cardio',
    'Rowing Machine': 'Cardio', 'Air Bike': 'Cardio', 'Jump Rope': 'Cardio',
    'Battle Ropes': 'Cardio', 'Elliptical Trainer': 'Cardio',
    'Stair Machine (Floors)': 'Cardio', 'Stair Machine (Steps)': 'Cardio',
    'Aerobics': 'Cardio', 'Walking': 'Cardio',
}

#Map primary muscle group using simple replace - values are plain strings now
df3['muscle_group'] = df3['exercise_name'].replace(MUSCLE_MAP)

#Any exercise not in the map keeps its original name; mark those as 'other'
known = set(MUSCLE_MAP.keys())
df3.loc[~df3['exercise_name'].isin(known), 'muscle_group'] = 'other'

unmapped = df3.loc[df3['muscle_group'] == 'other', 'exercise_name'].unique()
print(f'{len(unmapped)} unmapped exercises:')
print(unmapped)
# Out:
# 0 unmapped exercises:
# []

# %% [markdown]
# ### 2.3 Feature Engineering
#
#
# | Metric | Formula |
# |---|---|
# | **Volume** | `weight × reps` |
# | **Work Rate** | `total session volume for muscle group ÷ proportional session time` |
# | **Frequency** | unique days trained per muscle group per week |
# | **1RM (Brzycki)** | `weight / (1.0278 − 0.0278 × reps)` |

# %%
#Volume
df3['volume'] = df3['weight'] * df3['reps']

#Work Rate
#Step 1 - fix inflated durations first (same issue: timer left running)
df3['duration_min'] = df3['duration_min'].astype(float)
valid_mean_df3 = df3.loc[df3['duration_min'] <= 180, 'duration_min'].mean()
df3.loc[df3['duration_min'] > 180, 'duration_min'] = valid_mean_df3
df3['duration_min'] = df3['duration_min'].round(0).astype(int)

#Step 2 - proportional time per muscle group within the session
df3['muscle_sets']    = df3.groupby(['date', 'muscle_group'])['muscle_group'].transform('count')
df3['total_sets_day'] = df3.groupby('date')['date'].transform('count')
df3['duration_muscle_group'] = (
    df3['duration_min'] * (df3['muscle_sets'] / df3['total_sets_day'])
)

#Step 3 - total volume per muscle group per session
df3['total_volume_muscle_group'] = df3.groupby(['date', 'muscle_group'])['volume'].transform('sum')

#Step 4 - work rate
df3['work_rate'] = df3['total_volume_muscle_group'] / df3['duration_muscle_group']

#Frequency
temp3 = df3[['date', 'muscle_group', 'year', 'week']].drop_duplicates()
freq3 = temp3.groupby(['year', 'week', 'muscle_group'])['date'].transform('count')
df3 = df3.merge(
    temp3.assign(frequency=freq3),
    on=['date', 'muscle_group', 'year', 'week'],
    how='left'
)

#1RM via Brzycki formula
df3['1RM']     = df3['weight'] / (1.0278 - 0.0278 * df3['reps'])
df3['max_1RM'] = df3.groupby(['date', 'exercise_name'])['1RM'].transform('max')

#Final column order
col_order = ['date', 'year', 'week', 'muscle_group', 'exercise_name',
             'weight', 'reps', 'volume', 'work_rate', 'frequency', 'max_1RM']
df3 = df3[[c for c in col_order if c in df3.columns]]

print(f'df3 ready: {df3.shape[0]:,} rows x {df3.shape[1]} cols')
df3.head()
# Out:
# df3 ready: 3,083 rows x 11 cols
#          date  year  week muscle_group          exercise_name  weight  reps  \
# 0  2026-03-27  2026    13   Quadriceps        Squat (Barbell)   225.0   5.0
# 1  2026-03-27  2026    13   Quadriceps        Squat (Barbell)   280.0   5.0
# 2  2026-03-27  2026    13   Quadriceps        Squat (Barbell)   280.0   5.0
# 3  2026-03-26  2026    13        Chest  Bench Press (Barbell)   240.0   5.0
# 4  2026-03-26  2026    13        Chest  Bench Press (Barbell)   240.0   4.0
#
#    volume   work_rate  frequency     max_1RM
# 0  1125.0  112.142857          2  315.031503
# 1  1400.0  112.142857          2  315.031503
# 2  1400.0  112.142857          2  315.031503
# 3  1200.0  186.939891          2  270.027003
# 4   960.0  186.939891          2  270.027003

# %% [markdown]
# ---
# ## Part 3 - EDA on Hevy Data
# With features engineered, we now explore the data visually. The goal is to surface trends in volume, frequency, and strength over time - keeping charts simple and readable.

# %% [markdown]
# ### 3.1 Weekly Training Frequency per Muscle Group
#
# The step from ~1 to ~2 days/week across most groups (Chest, Biceps, Lats, Triceps, Upper Back) marks exactly when I switched to a higher-frequency split in early 2025. Accessory groups like Calves and Traps stayed at 1x/week - I never deliberately programmed those, just hit them as secondary muscles.

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np

plt.rcParams['figure.figsize'] = (13, 4)
plt.rcParams['axes.titlesize']  = 12
plt.rcParams['axes.titleweight'] = 'bold'
plt.rcParams['axes.spines.top']  = False
plt.rcParams['axes.spines.right'] = False

weekly_freq = (
    df3[df3['muscle_group'] != 'other']
    .groupby(['year', 'week', 'muscle_group'])
    .agg(frequency=('frequency', 'max'), date=('date', 'min'))
    .reset_index()
)
weekly_freq['date'] = pd.to_datetime(weekly_freq['date'])

all_groups = sorted(weekly_freq['muscle_group'].unique())
cmap   = plt.colormaps['tab20'].resampled(len(all_groups))
colors = {mg: cmap(i) for i, mg in enumerate(all_groups)}

N_COLS = 4
n_rows = int(np.ceil(len(all_groups) / N_COLS))

fig, axes = plt.subplots(n_rows, N_COLS,
                         figsize=(16, n_rows * 3),
                         sharey=True)
axes = axes.flatten()

for idx, mg in enumerate(all_groups):
    ax  = axes[idx]
    sub = (weekly_freq[weekly_freq['muscle_group'] == mg]
           .sort_values('date')
           .copy())

    # 4-week rolling mean on date-sorted series
    sub['rolling'] = sub['frequency'].rolling(4, min_periods=1).mean()

    color = colors[mg]
    ax.scatter(sub['date'], sub['frequency'],
               color=color, alpha=0.25, s=14, zorder=2)
    ax.plot(sub['date'], sub['rolling'],
            color=color, lw=2, zorder=3)

    ax.set_title(mg, fontsize=9, fontweight='bold', pad=4)
    ax.set_ylabel('days/wk', fontsize=7)
    ax.set_yticks([1, 2, 3])
    ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y"))
    ax.xaxis.set_major_locator(mdates.YearLocator())
    plt.setp(ax.xaxis.get_majorticklabels(), rotation=45, ha='right', fontsize=7)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

# hide unused subplots
for idx in range(len(all_groups), len(axes)):
    axes[idx].set_visible(False)

fig.suptitle('Weekly Training Frequency per Muscle Group\n(dots = raw weekly count, line = 4-week rolling mean)',
             fontsize=12, fontweight='bold', y=1.01)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3.2 Work Rate by Muscle Group
#
# Work rate stayed relatively flat across the split change - I didn't intend to train harder per session, just more often. The gradual upward drift in Biceps and Chest reflects progressive overload over time, not a deliberate intensity increase. Calves and Upper Back remain inflated due to high-rep machine work skewing the volume-per-minute calculation.

# %%
weekly_wr = (
    df3[df3['muscle_group'] != 'other']
    .drop_duplicates(subset=['date', 'muscle_group'])
    .groupby(['year', 'week', 'muscle_group'])
    .agg(avg_work_rate=('work_rate', 'mean'), date=('date', 'min'))
    .reset_index()
)
weekly_wr['date'] = pd.to_datetime(weekly_wr['date'])

fig, axes = plt.subplots(n_rows, N_COLS,
                         figsize=(16, n_rows * 3),
                         sharey=False)
axes = axes.flatten()

for idx, mg in enumerate(all_groups):
    ax  = axes[idx]
    sub = (weekly_wr[weekly_wr['muscle_group'] == mg]
           .sort_values('date')
           .copy())
    if sub.empty:
        ax.set_visible(False)
        continue

    sub['rolling'] = sub['avg_work_rate'].rolling(4, min_periods=1).mean()

    color = colors[mg]
    ax.scatter(sub['date'], sub['avg_work_rate'],
               color=color, alpha=0.25, s=14, zorder=2)
    ax.plot(sub['date'], sub['rolling'],
            color=color, lw=2, zorder=3)

    ax.set_title(mg, fontsize=9, fontweight='bold', pad=4)
    ax.set_ylabel('kg·reps/min', fontsize=7)
    ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y"))
    ax.xaxis.set_major_locator(mdates.YearLocator())
    plt.setp(ax.xaxis.get_majorticklabels(), rotation=45, ha='right', fontsize=7)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

for idx in range(len(all_groups), len(axes)):
    axes[idx].set_visible(False)

fig.suptitle('Work Rate by Muscle Group Over Time\n(dots = raw weekly avg, line = 4-week rolling mean)',
             fontsize=12, fontweight='bold', y=1.01)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3.3 Estimated 1RM by Muscle Group
#
# 1RM gains appear roughly 3–4 months after the frequency increase, most clearly in Biceps, Chest, and Hamstrings - suggesting the extra weekly volume took time to accumulate into measurable strength. Shoulders and Triceps remain noisy because the exercise variety within those groups is too broad for a clean signal. The Lats dip right after the gap is detraining, not regression - it recovers and likely exceeds the pre-gap baseline by early 2026.

# %%
weekly_1rm = (
    df3[df3['muscle_group'] != 'other']
    .groupby(['year', 'week', 'muscle_group'])
    .agg(max_1rm=('max_1RM', 'mean'), date=('date', 'min'))
    .reset_index()
)
weekly_1rm['date'] = pd.to_datetime(weekly_1rm['date'])

fig, axes = plt.subplots(n_rows, N_COLS,
                         figsize=(16, n_rows * 3),
                         sharey=False)
axes = axes.flatten()

for idx, mg in enumerate(all_groups):
    ax  = axes[idx]
    sub = (weekly_1rm[weekly_1rm['muscle_group'] == mg]
           .sort_values('date')
           .copy())
    if sub.empty:
        ax.set_visible(False)
        continue

    sub['rolling'] = sub['max_1rm'].rolling(4, min_periods=1).mean()

    color = colors[mg]
    ax.scatter(sub['date'], sub['max_1rm'],
               color=color, alpha=0.25, s=14, zorder=2)
    ax.plot(sub['date'], sub['rolling'],
            color=color, lw=2, zorder=3)

    ax.set_title(mg, fontsize=9, fontweight='bold', pad=4)
    ax.set_ylabel('Avg Est. 1RM (kg)', fontsize=7)
    ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y"))
    ax.xaxis.set_major_locator(mdates.YearLocator())
    plt.setp(ax.xaxis.get_majorticklabels(), rotation=45, ha='right', fontsize=7)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

for idx in range(len(all_groups), len(axes)):
    axes[idx].set_visible(False)

fig.suptitle('Estimated 1RM by Muscle Group Over Time\n(dots = weekly avg across exercises, line = 4-week rolling mean)',
             fontsize=12, fontweight='bold', y=1.01)
plt.tight_layout()
plt.show()

# %%
df3.to_csv('data/clean/clean1.csv', index=False)

# %% [markdown]
# ### Summary
#
# I have a significant data gap between mid-2023 and late-2024, which makes trends during that period unreliable. The gaps vary across muscle groups, suggesting inconsistent tracking rather than a complete stop in training.
#
# The most important change in my training occurs in early 2025: **my training frequency nearly doubles (from ~1x to ~2x per week)** across most muscle groups. However, **my work rate per session remains relatively constant**, indicating that I wasn’t training harder—just more often. As a result, my total weekly volume increased.
#
# My strength gains (1RM) **do not increase immediately**. Instead, there is a **3–5 month lag** after the increase in frequency. This pattern is especially clear in muscle groups like chest, biceps, and hamstrings, suggesting that the higher frequency (and total volume) drives strength improvements over time.
#
# There are some inconsistencies in the data:
# - **Shoulders and triceps** show noisy or unreliable 1RM trends, likely due to exercise variation and limitations in estimation methods.
# - **Lats** show a temporary drop, which likely reflects detraining after the gap.
# - **Calves** appear inflated due to inaccuracies in high-repetition 1RM estimation.
#
# ### Core Insight
#
# Overall, my data tells a consistent story: after a break, I returned to training, increased my frequency without increasing intensity, and over several months, that higher volume led to measurable strength gains.
#
# ### Limitation
#
# Due to the missing data, it is difficult to fully determine whether **frequency or work rate has a stronger causal relationship with 1RM**.
#
# However, for major muscle groups that I train consistently, the data suggests that **strength gains correlate more strongly with increases in training frequency (volume)** than with per-session work rate.

# %% [markdown]
# ### Power BI Dashboard Overview
# !["Dashboard"](https://github.com/TonyDeDev/personal-trainning-data-analysis/blob/main/dashboard/dashboardOverview.png)

# %% [markdown]
# !["Dashboard - Squat (Barbell)"](https://github.com/TonyDeDev/personal-trainning-data-analysis/blob/main/dashboard/dashboardSquat.png)

# %% [markdown]
# !["Dashboard - Lat Pulldown (Cable)"](https://github.com/TonyDeDev/personal-trainning-data-analysis/blob/main/dashboard/dashboardSquat.png)

# %%
!["Dashboard - Bench Press (Barbell)"](https://github.com/TonyDeDev/personal-trainning-data-analysis/blob/main/dashboard/dashboardBenchPress.png)
